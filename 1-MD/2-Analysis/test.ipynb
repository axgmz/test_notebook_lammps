# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,5,100)
y = np.sqrt(x)

plt.plot(x,y,label="line")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Title")
plt.show()
